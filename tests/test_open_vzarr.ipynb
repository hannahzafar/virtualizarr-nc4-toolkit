# %%
import xarray as xr

# %%
test_path = "micasa_test/vstore.parquet"

# %%
# !ls micasa_test/vstore.parquet

# %%
ds = xr.open_dataset(f"reference::{test_path}", engine="zarr", consolidated=False)

# %%
ds

# %%
# from virtualizarr.parsers import KerchunkJSONParser, KerchunkParquetParser
